# %% [markdown]
# ## Message Label

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
messages = [
    SystemMessage(content="You are a helpful assistant."),  
    HumanMessage(content="Hello, who won the world series in 2020?"),
    AIMessage(content="The Los Angeles Dodgers won the World Series in 2020."),
    HumanMessage(content="Where was it played?")
]
messages
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hello, who won the world series in 2020?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='The Los Angeles Dodgers won the World Series in 2020.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Where was it played?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## Prompt Template

# %%
from langchain_core.prompts import PromptTemplate
instruction = "create a human like"
prompt = PromptTemplate(
    template = "{instructions} my name is {name}",
    variale_name = ["name"],
    partial_variable = {"instructions": instruction})

# %%
prompt.invoke({"name": "Alice", "instructions": "Answer the following question truthfully." })
# Out:
# StringPromptValue(text='Answer the following question truthfully. my name is Alice')

# %% [markdown]
# ## ChatPromptTemplate

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate([
    SystemMessage(content="You are a helpful assistant."),  
    HumanMessage(content="Hello, who won the world series in 2020?"),
    AIMessage(content="TChatPromptTemplatehe Los Angeles Dodgers won the World Series in 2020."),
    HumanMessage(content="Where was it {played}?")
])

# %%
prompt.invoke({"played": "held" })
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, who won the world series in 2020?', additional_kwargs={}, response_metadata={}), AIMessage(content='TChatPromptTemplatehe Los Angeles Dodgers won the World Series in 2020.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Where was it {played}?', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## MessagePlace holder

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate(
    messages = [
        MessagesPlaceholder(variable_name="history"),
        ("human","Tell me a joke on {topic} .")
    ]
)

# %%
hist =  [AIMessage(content="Why did the scarecrow win an award? Because he was outstanding in his field!")]
res = prompt.invoke({"topic":"ipl","history":hist})
print(res)
# Out:
# messages=[AIMessage(content='Why did the scarecrow win an award? Because he was outstanding in his field!', additional_kwargs={}, response_metadata={}), HumanMessage(content='Tell me a joke on ipl .', additional_kwargs={}, response_metadata={})]
