# %% [markdown]
# ## Groq

# %%
! pip install langchain-groq dotenv

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(
    model="openai/gpt-oss-20b",     # example model
    temperature=0.0,
    reasoning_format="hidden"
)

# %%
response = llm.invoke("What is the capital of France?")
response.content
# Out:
# 'The capital of France is **Paris**.'

# %% [markdown]
# ## OpenAI

# %%
# !pip install langchain_openai
# Out:
# Collecting langchain_openai
#   Downloading langchain_openai-1.0.2-py3-none-any.whl (81 kB)
#      -------------------------------------- 81.9/81.9 kB 919.2 kB/s eta 0:00:00
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.2 in e:\langchain\venv\lib\site-packages (from langchain_openai) (1.0.4)
# Collecting openai<3.0.0,>=1.109.1
#   Downloading openai-2.7.2-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.4 MB/s eta 0:00:00
# Collecting tiktoken<1.0.0,>=0.7.0
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#      -------------------------------------- 879.4/879.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.2->langchain_openai) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\langchain\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\langchain\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.28.1)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.12.0-cp311-cp311-win_amd64.whl (204 kB)
#      -------------------------------------- 204.9/204.9 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in e:\langchain\venv\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Collecting tqdm>4
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting regex>=2022.1.18
#   Using cached regex-2025.11.3-cp311-cp311-win_amd64.whl (277 kB)
# Requirement already satisfied: requests>=2.26.0 in e:\langchain\venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in e:\langchain\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: certifi in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.2->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain_openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain_openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.2->langchain_openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain_openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.2->langchain_openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\langchain\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.5.0)
# Requirement already satisfied: colorama in e:\langchain\venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain_openai) (0.4.6)
# Installing collected packages: tqdm, regex, jiter, tiktoken, openai, langchain_openai
# Successfully installed jiter-0.12.0 langchain_openai-1.0.2 openai-2.7.2 regex-2025.11.3 tiktoken-0.12.0 tqdm-4.67.1
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model = "gpt-4o",
)

# %%
response = llm.invoke("What is the capital of France?")
response.content

# %% [markdown]
# ## Google Gemini

# %%
! pip install langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-3.0.2-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.5/55.5 kB 573.2 kB/s eta 0:00:00
# Collecting filetype<2.0.0,>=1.2.0
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting google-ai-generativelanguage<1.0.0,>=0.7.0
#   Using cached google_ai_generativelanguage-0.9.0-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in e:\langchain\venv\lib\site-packages (from langchain-google-genai) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in e:\langchain\venv\lib\site-packages (from langchain-google-genai) (2.12.4)
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1
#   Using cached google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1
#   Using cached google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Collecting grpcio<2.0.0,>=1.33.2
#   Using cached grpcio-1.76.0-cp311-cp311-win_amd64.whl (4.7 MB)
# Collecting proto-plus<2.0.0,>=1.22.3
#   Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in e:\langchain\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.32.5)
# Collecting grpcio-status<2.0.0,>=1.33.2
#   Using cached grpcio_status-1.76.0-py3-none-any.whl (14 kB)
# Collecting cachetools<7.0,>=2.0.0
#   Using cached cachetools-6.2.1-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: jsonpointer>=1.9 in e:\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.25.0)
# Requirement already satisfied: anyio in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (4.11.0)
# Requirement already satisfied: certifi in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: idna in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (0.16.0)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in e:\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-google-genai) (1.3.1)
# Installing collected packages: filetype, pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-ai-generativelanguage, langchain-google-genai
# Successfully installed cachetools-6.2.1 filetype-1.2.0 google-ai-generativelanguage-0.9.0 google-api-core-2.28.1 google-auth-2.43.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 grpcio-status-1.76.0 langchain-google-genai-3.0.2 proto-plus-1.26.1 protobuf-6.33.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",  # example model
    temperature=0.0,
)

# %%
llm.invoke("What is the capital of France?").content
# Out:
# 'The capital of France is **Paris**.'

# %% [markdown]
# ## Huggingface

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Collecting transformers<5.0.0,>=4.41.0
#   Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Requirement already satisfied: tqdm in e:\langchain\venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0
#   Using cached torch-2.9.0-cp311-cp311-win_amd64.whl (109.3 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp311-cp311-win_amd64.whl (8.9 MB)
# Collecting scipy
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
# Collecting huggingface-hub>=0.20.0
#   Using cached huggingface_hub-1.1.2-py3-none-any.whl (514 kB)
# Collecting Pillow
#   Using cached pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
# Requirement already satisfied: typing_extensions>=4.5.0 in e:\langchain\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Collecting filelock
#   Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Collecting hf-xet<2.0.0,>=1.2.0
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in e:\langchain\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\langchain\venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Collecting shellingham
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting typer-slim
#   Using cached typer_slim-0.20.0-py3-none-any.whl (47 kB)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting networkx>=2.5.1
#   Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Requirement already satisfied: colorama in e:\langchain\venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Collecting huggingface-hub>=0.20.0
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Collecting numpy>=1.17
#   Using cached numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in e:\langchain\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in e:\langchain\venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: anyio in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: certifi in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in e:\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in e:\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain\venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\langchain\venv\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Collecting click>=8.0.0
#   Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Requirement already satisfied: sniffio>=1.1 in e:\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Installing collected packages: mpmath, threadpoolctl, sympy, safetensors, Pillow, numpy, networkx, MarkupSafe, joblib, fsspec, filelock, scipy, jinja2, huggingface-hub, torch, tokenizers, scikit-learn, transformers, sentence-transformers
# Successfully installed MarkupSafe-3.0.3 Pillow-12.0.0 filelock-3.20.0 fsspec-2025.10.0 huggingface-hub-0.36.0 jinja2-3.1.6 joblib-1.5.2 mpmath-1.3.0 networkx-3.5 numpy-2.3.4 safetensors-0.6.2 scikit-learn-1.7.2 scipy-1.16.3 sentence-transformers-5.1.2 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.1 torch-2.9.0 transformers-4.57.1
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%capture
# !pip install langchain-huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

text = "Artificial intelligence is fascinating."
vector = embeddings.embed_query(text)

# %%
text = [
    "Artificial intelligence is fascinating.",
    "LangChain makes AI workflows modular."
]
vector = embeddings.embed_documents(text)

# %%
vector[0][:5], vector[1][:5]
# Out:
# ([-0.004465945065021515,
#   -0.06313364207744598,
#   0.06713645160198212,
#   6.86296698404476e-05,
#   -0.01173859741538763],
#  [-0.10179848968982697,
#   -0.03672081232070923,
#   0.016263049095869064,
#   -0.050558511167764664,
#   0.004525497555732727])
